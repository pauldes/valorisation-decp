# %%
import os
os.chdir("..")
os.getcwd()
# Out:
# 'c:\\Users\\paul.desigaud\\code\\valorisation-decp'

# %%
import pandas
pandas.set_option("display.max_columns", None)

# %%
data = pandas.read_csv("./data/StockEtablissement_utf8.csv", sep=",", encoding="utf8", header=0, nrows=1000000)
# Out:
# C:\Users\paul.desigaud\.virtualenvs\valorisation-decp-qCRh_KLP\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7,12,18,20,22,24,25,27,28,29,31,33,34,36,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.sample(5)
# Out:
#             siren  nic           siret statutDiffusionEtablissement  \
# 709393  300990686  572  30099068600572                            O
# 703810  300903671   18  30090367100018                            O
# 418482  216303891   32  21630389100032                            O
# 918747  304053614   18  30405361400018                            O
# 556312  262501901   17  26250190100017                            O
#
#        dateCreationEtablissement trancheEffectifsEtablissement  \
# 709393                2018-09-05                           NaN
# 703810                       NaN                           NaN
# 418482                1999-01-01                            NN
# 918747                1968-01-01                            NN
# 556312                1986-01-01                            NN
#
#         anneeEffectifsEtablissement  \
# 709393                          NaN
# 703810                          NaN
# 418482                          NaN
# ...

# %%
data["nomenclatureActivitePrincipaleEtablissement"].value_counts(dropna=False)
# Out:
# NAFRev2    571973
# NAP        189923
# NAF1993    171372
# NAFRev1     61371
# NaN          5361
# Name: nomenclatureActivitePrincipaleEtablissement, dtype: int64

# %%
data[data["activitePrincipaleEtablissement"]=="84.11Z"][["siren", "siret", "libelleCommuneEtablissement", "caractereEmployeurEtablissement", "enseigne1Etablissement", "enseigne2Etablissement"]][data["enseigne1Etablissement"].notna()].sample(20)
# Out:
# C:\Users\PAUL~1.DES\AppData\Local\Temp/ipykernel_18280/1842350159.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data["activitePrincipaleEtablissement"]=="84.11Z"][["siren", "siret", "libelleCommuneEtablissement", "caractereEmployeurEtablissement", "enseigne1Etablissement", "enseigne2Etablissement"]][data["enseigne1Etablissement"].notna()].sample(20)
#             siren           siret libelleCommuneEtablissement  \
# 365618  213600349  21360034900053                     CHABRIS
# 305460  210101663  21010166300016                       FRANS
# 420566  216404004  21640400400014                     MONTAUT
# 228414  173302217  17330221701214                    BORDEAUX
# 354463  213003304  21300330400010                      TORNAC
# 341363  212402226  21240222600089                    LA FORCE
# 337001  212105852  21210585200017          SAULON-LA-CHAPELLE
# 408005  215904657  21590465700016                  POMMEREUIL
# ...

# %%
publics = data[data["activitePrincipaleEtablissement"]=="84.11Z"]
publics.to_csv("./data/StockEtablissement_utf8_84.11Z.csv")
